# %% [markdown]
# <a href="https://colab.research.google.com/github/OCE1984/MScDataAnaltyicsPrinciples/blob/main/DAP_W2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries/Packages

import math
import matplotlib.pyplot as plt
import random

# %%
# Variables

# String
first_name = 'Owen'
last_name = 'Evans'

#Integer
age = 40

# List
hobbies = ['movies','coffee','photography']

# Float
height = 187.5

new_age = float(age)
new_age
# Out:
# 40.0

# %%
# print(f'My name is {first_name} {last_name} and I am {age} years old')

# %%
# Functions
print(name)
print(age)
# Out:
# Owen
# 40

# %%
# Running features from libraries
math.pi
math.sqrt(16)
# Out:
# 4.0

# %%
fav_mov = ["It's a Wonderful Life", "Die Hard", "Arrival"]

# Colab only shows the value if it is the last line in the cell. Otherwise, use the 'print' function.
len(fav_mov)
# Out:
# 3

# %%
rating = [5,4,3.5]
plt.bar(fav_mov, rating)
plt.xlabel('Movie')
plt.ylabel('Rating')
plt.title('My Favorite Movies')
plt.show()

# %%
num_samples = 100  # Number of ages to generate
min_age = 1        # Minimum age
max_age = 100      # Maximum age

# Generate the dataset
ages = [random.randint(min_age, max_age) for _ in range(num_samples)]

plt.hist(ages, bins=15, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages')
plt.show()

# %%
age = [10,50,45,12,60,40,30]
plt.hist(age,bins=15)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages')
plt.show()

# %%
#Q1
country = ["Belgium","France","Germany","Spain","UK"]
population = [11.46,66.99,83.02,46.94,66.65]




plt.bar(country,population)
plt.xlabel('Country')
plt.ylabel('Population (in M)')
plt.title('Population of Countries')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
country = ["Belgium", "France", "Germany", "Spain", "UK"]
population = [11.46, 66.99, 83.02, 46.94, 66.65]
colors = ["black", "black", "black", "black", "black"]

# Highlight the country with the maximum population
max_index = population.index(max(population))
colors[max_index] = "red"

# Plot the bar chart with the color list
plt.bar(country, population, color=colors)

# Add labels and title
plt.xlabel('Country')
plt.ylabel('Population (in M)')
plt.title('Population of Countries')

# Show the plot
plt.show()

# %%
# Q2

Test_1 = [59,52,44,51,42,42,41,45,27,63,54,44,50,47]
Test_2 = [60,63,55,50,66,48,58,45,13,50,60,56,64,50]

plt.scatter(Test_1,Test_2)
plt.xlabel('Test 1')
plt.ylabel('Test 2')
plt.title('Scatter Plot of Test Scores')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for test scores
Test_1 = [59, 52, 44, 51, 42, 42, 41, 45, 27, 63, 54, 44, 50, 47]
Test_2 = [60, 63, 55, 50, 66, 48, 58, 45, 13, 50, 60, 56, 64, 50]

# Scatter plot
plt.scatter(Test_1, Test_2, label="Data points", color="blue")

# Calculate the trendline
coefficients = np.polyfit(Test_1, Test_2, 1)  # Linear fit (degree=1)
trendline = np.poly1d(coefficients)

# Generate x-values for the trendline
x_vals = np.linspace(min(Test_1), max(Test_1), 100)
y_vals = trendline(x_vals)

# Plot the trendline
plt.plot(x_vals, y_vals, color="red", label="Trendline")

# Add labels, title, and legend
plt.xlabel('Test 1')
plt.ylabel('Test 2')
plt.title('Scatter Plot of Test Scores with Trendline')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Data for test scores
Test_1 = [59, 52, 44, 51, 42, 42, 41, 45, 27, 63, 54, 44, 50, 47]
Test_2 = [60, 63, 55, 50, 66, 48, 58, 45, 13, 50, 60, 56, 64, 50]

# Convert data to 2D arrays for sklearn
X = np.array(Test_1).reshape(-1, 1)  # Feature (independent variable)
y = np.array(Test_2)                # Target (dependent variable)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Get the regression line
X_range = np.linspace(min(Test_1), max(Test_1), 100).reshape(-1, 1)
y_pred = model.predict(X_range)

# Scatter plot
plt.scatter(Test_1, Test_2, color="blue", label="Data points")

# Regression line
plt.plot(X_range, y_pred, color="red", label="Regression Line")

# Add labels, title, and legend
plt.xlabel('Test 1')
plt.ylabel('Test 2')
plt.title('Scatter Plot with Linear Regression')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np

# Data for test scores
Test_1 = [59, 52, 44, 51, 42, 42, 41, 45, 27, 63, 54, 44, 50, 47]
Test_2 = [60, 63, 55, 50, 66, 48, 58, 45, 13, 50, 60, 56, 64, 50]

# Convert data to 2D arrays for sklearn
X = np.array(Test_1).reshape(-1, 1)  # Feature (independent variable)
y = np.array(Test_2)                # Target (dependent variable)

# Create polynomial features (degree=2 for quadratic regression)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Fit a linear regression model to the polynomial features
model = LinearRegression()
model.fit(X_poly, y)

# Generate predictions for the polynomial regression line
X_range = np.linspace(min(Test_1), max(Test_1), 100).reshape(-1, 1)
X_range_poly = poly.transform(X_range)  # Transform the range into polynomial features
y_pred = model.predict(X_range_poly)

# Scatter plot
plt.scatter(Test_1, Test_2, color="blue", label="Data points")

# Polynomial regression line
plt.plot(X_range, y_pred, color="red", label="Polynomial Regression (degree=2)")

# Add labels, title, and legend
plt.xlabel('Test 1')
plt.ylabel('Test 2')
plt.title('Scatter Plot with Polynomial Regression')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Data for test scores
Test_1 = [59, 52, 44, 51, 42, 42, 41, 45, 27, 63, 54, 44, 50, 47]
Test_2 = [60, 63, 55, 50, 66, 48, 58, 45, 13, 50, 60, 56, 64, 50]

# Convert data to 2D arrays for sklearn
X = np.array(Test_1).reshape(-1, 1)  # Feature (independent variable)
y = np.array(Test_2)                # Target (dependent variable)

# Degrees to test
degrees = [1, 2, 3, 4, 5]

# Store metrics for each degree
mse_list = []
r2_list = []

plt.figure(figsize=(12, 8))  # Set the figure size

for degree in degrees:
    # Create polynomial features
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X)

    # Fit the regression model
    model = LinearRegression()
    model.fit(X_poly, y)

    # Generate predictions
    X_range = np.linspace(min(Test_1), max(Test_1), 100).reshape(-1, 1)
    X_range_poly = poly.transform(X_range)
    y_pred = model.predict(X_range_poly)

    # Calculate MSE and R²
    y_train_pred = model.predict(X_poly)
    mse = mean_squared_error(y, y_train_pred)
    r2 = r2_score(y, y_train_pred)
    mse_list.append(mse)
    r2_list.append(r2)

    # Plot the polynomial regression line
    plt.plot(X_range, y_pred, label=f'Degree {degree} (MSE={mse:.2f}, R²={r2:.2f})')

# Scatter plot of original data
plt.scatter(Test_1, Test_2, color="blue", label="Data points", zorder=5)

# Add labels, title, and legend
plt.xlabel('Test 1')
plt.ylabel('Test 2')
plt.title('Polynomial Regression for Different Degrees')
plt.legend()
plt.show()
